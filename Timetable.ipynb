# %%
import pandas as pd

# %%
#from google.colab import drive

# %%
#drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#os.chdir('/content/gdrive/My Drive/Colab Data')

# %%
f=input("Enter Time table path with file name")
f1=input("Enter your subject name file")
df=pd.read_csv(f)
df2=pd.read_csv(f1)

# %%
df
# Out:
#     Sr. No.  ...  Password
# 0       NaN  ...       NaN
# 1       NaN  ...       NaN
# 2       1.0  ...  282998.0
# 3       2.0  ...  371054.0
# 4       3.0  ...  513723.0
# 5       4.0  ...  957047.0
# 6       5.0  ...  170891.0
# 7       6.0  ...  613252.0
# 8       7.0  ...  871954.0
# 9       8.0  ...  156451.0
# 10      9.0  ...  281626.0
# 11     10.0  ...  262117.0
# 12     11.0  ...  372448.0
# 13     12.0  ...  657981.0
# 14     13.0  ...  804807.0
# 15     14.0  ...  389182.0
# 16     15.0  ...  857315.0
# 17     16.0  ...  642341.0
# 18     17.0  ...  122366.0
# 19     18.0  ...  585108.0
# 20     19.0  ...  163330.0
# 21      NaN  ...       NaN
# 22      1.0  ...  130752.0
# 23      2.0  ...  597509.0
# 24      3.0  ...  627613.0
# 25      4.0  ...  231514.0
# 26      5.0  ...  209154.0
# 27      6.0  ...  688570.0
# 28      7.0  ...  102636.0
# 29      8.0  ...  691008.0
# 30      9.0  ...  193714.0
# 31     10.0  ...  721137.0
# 32     11.0  ...  284111.0
# ...

# %%
df2
# Out:
#                 Subject Section
# 0             Markstrat       A
# 1  Strategic Management       B
# 2  Business Forecasting       A

# %%
def subject_name():
  for k in range(len(df2)):
    subject=df2['Subject'][k]
    section=df2['Section'][k]
    for j in range(0, len(df)):
      if subject in str(df['Name of the course'][j]):
        if section in df['Name of the course'][j].split("Section - ")[1]:
          print(df['Name of the course'][j],df['Date'][j],df['Time'][j],df['Zoom Session Link'][j])

# %%
subject_name()
# Out:
# Markstrat (Prof. Anita Baslingappa) Section - A 27-Jul-2020 9:00:00 AM https://zoom.us/j/99583203147?pwd=WmtYYWkxTjZHemsxWXZEMS92MFJwdz09
# Strategic Management ( Prof. Subrat Sarangi ) Section - B 27-Jul-2020 9:00:00 AM https://zoom.us/j/93363738824?pwd=TVludmkwZkw5MjZJQTdKL2MwOGdPZz09
# Strategic Management ( Prof. Subrat Sarangi ) Section - B 29-Jul-2020 10:00:00 AM https://zoom.us/j/95567442084?pwd=WWVEeHk2VkFLU05zVXVPRjkwRHl5Zz09
# Business Forecasting ( Prof. Niyati Bhanja ) Section - A 27-Jul-2020 2:00:00 PM https://zoom.us/j/95392856587?pwd=VWo4dUVxRXFqUmNxUWVhNVBuNWhtZz09
